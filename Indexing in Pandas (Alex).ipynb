# %%
import pandas as pd

# %%
df = pd.read_csv (r"C:\Users\otabek.khamidov\Desktop\Data Analytics\Alex-Data_Analyst_Bootcamp\Pandas\world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
# index_col = "" -> bu orqali birinchi index Country dan boshlanadigan qildik.
df = pd.read_csv (r"C:\Users\otabek.khamidov\Desktop\Data Analytics\Alex-Data_Analyst_Bootcamp\Pandas\world_population.csv", index_col = "Country")
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
# bizga hozir Country index bop' qoldi. Lekin bizga boshida kiritgan df kerak.
df.reset_index(inplace = True)
df
# Out:
#      index            Country  Rank CCA3           Capital Continent  \
# 0        0        Afghanistan    36  AFG             Kabul      Asia
# 1        1            Albania   138  ALB            Tirana    Europe
# 2        2            Algeria    34  DZA           Algiers    Africa
# 3        3     American Samoa   213  ASM         Pago Pago   Oceania
# 4        4            Andorra   203  AND  Andorra la Vella    Europe
# ..     ...                ...   ...  ...               ...       ...
# 229    229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230    230     Western Sahara   172  ESH          El Aaiún    Africa
# 231    231              Yemen    46  YEM             Sanaa      Asia
# 232    232             Zambia    63  ZMB            Lusaka    Africa
# 233    233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %%
# index nomini o'zgartirishning ikkinchi usuli
df.set_index("Country", inplace = True)
df
# Out:
#                    index CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan            0  AFG             Kabul      Asia       41128771.0
# Albania                1  ALB            Tirana    Europe        2842321.0
# Algeria                2  DZA           Algiers    Africa       44903225.0
# American Samoa         3  ASM         Pago Pago   Oceania          44273.0
# Andorra                4  AND  Andorra la Vella    Europe          79824.0
# ...                  ...  ...               ...       ...              ...
# Wallis and Futuna    229  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara       230  ESH          El Aaiún    Africa         575986.0
# Yemen                231  YEM             Sanaa      Asia       33696614.0
# Zambia               232  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             233  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
# Yemen indexiga tegishli barcha elementlar chiqadi.
df.loc["Yemen"]
# Out:
# index                                 231
# CCA3                                  YEM
# Capital                             Sanaa
# Continent                            Asia
# 2022 Population                33696614.0
# 2020 Population                32284046.0
# 2015 Population                28516545.0
# 2010 Population                24743946.0
# 2000 Population                18628700.0
# 1990 Population                13375121.0
# 1980 Population                 9204938.0
# 1970 Population                 6843607.0
# Area (km²)                       527968.0
# Density (per km²)                 63.8232
# Growth Rate                        1.0217
# World Population Percentage          0.42
# Name: Yemen, dtype: object

# %%
# Yemen indexiga tegishli barcha elementlar chiqadi.
df.iloc[-3]
# Out:
# Rank                                   46
# CCA3                                  YEM
# Capital                             Sanaa
# Continent                            Asia
# 2022 Population                33696614.0
# 2020 Population                32284046.0
# 2015 Population                28516545.0
# 2010 Population                24743946.0
# 2000 Population                18628700.0
# 1990 Population                13375121.0
# 1980 Population                 9204938.0
# 1970 Population                 6843607.0
# Area (km²)                       527968.0
# Density (per km²)                 63.8232
# Growth Rate                        1.0217
# World Population Percentage          0.42
# Name: Yemen, dtype: object

# %%
# bizga hozir Country index bo'p qoldi. Lekin bizga boshida kiritgan df kerak.
df.reset_index(inplace = True)
df
# Out:
#                Country  index CCA3           Capital Continent  \
# 0          Afghanistan      0  AFG             Kabul      Asia
# 1              Albania      1  ALB            Tirana    Europe
# 2              Algeria      2  DZA           Algiers    Africa
# 3       American Samoa      3  ASM         Pago Pago   Oceania
# 4              Andorra      4  AND  Andorra la Vella    Europe
# ..                 ...    ...  ...               ...       ...
# 229  Wallis and Futuna    229  WLF          Mata-Utu   Oceania
# 230     Western Sahara    230  ESH          El Aaiún    Africa
# 231              Yemen    231  YEM             Sanaa      Asia
# 232             Zambia    232  ZMB            Lusaka    Africa
# 233           Zimbabwe    233  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# ...

# %%
df = pd.read_csv (r"C:\Users\otabek.khamidov\Desktop\Data Analytics\Alex-Data_Analyst_Bootcamp\Pandas\world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.set_index(["Country", "Capital"], inplace = True)
df
# Out:
#                                     Rank CCA3 Continent  2022 Population  \
# Country           Capital
# Afghanistan       Kabul               36  AFG      Asia       41128771.0
# Albania           Tirana             138  ALB    Europe        2842321.0
# Algeria           Algiers             34  DZA    Africa       44903225.0
# American Samoa    Pago Pago          213  ASM   Oceania          44273.0
# Andorra           Andorra la Vella   203  AND    Europe          79824.0
# ...                                  ...  ...       ...              ...
# Wallis and Futuna Mata-Utu           226  WLF   Oceania          11572.0
# Western Sahara    El Aaiún           172  ESH    Africa         575986.0
# Yemen             Sanaa               46  YEM      Asia       33696614.0
# Zambia            Lusaka              63  ZMB    Africa       20017675.0
# Zimbabwe          Harare              74  ZWE    Africa       16320537.0
#
# ...

# %%
# sort indexing 
df.sort_index(ascending = True)
# Out:
#                                                       Rank CCA3  \
# Country                          Capital
# Afghanistan                      Kabul                  36  AFG
# Albania                          Tirana                138  ALB
# Algeria                          Algiers                34  DZA
# American Samoa                   Pago Pago             213  ASM
# Andorra                          Andorra la Vella      203  AND
# Angola                           Luanda                 42  AGO
# Anguilla                         The Valley            224  AIA
# Antigua and Barbuda              Saint John’s          201  ATG
# Argentina                        Buenos Aires           33  ARG
# Armenia                          Yerevan               140  ARM
# Aruba                            Oranjestad            198  ABW
# Australia                        Canberra               55  AUS
# Austria                          Vienna                 99  AUT
# ...

# %%
pd.set_option("display.max.rows", 235)

# %%
# sort indexing 
df.sort_index(ascending = False)
# Out:
#                                                       Rank CCA3  \
# Country                          Capital
# Zimbabwe                         Harare                 74  ZWE
# Zambia                           Lusaka                 63  ZMB
# Yemen                            Sanaa                  46  YEM
# Western Sahara                   El Aaiún              172  ESH
# Wallis and Futuna                Mata-Utu              226  WLF
# Vietnam                          Hanoi                  16  VNM
# Venezuela                        Caracas                51  VEN
# Vatican City                     Vatican City          234  VAT
# Vanuatu                          Port-Vila             181  VUT
# Uzbekistan                       Tashkent               43  UZB
# Uruguay                          Montevideo            133  URY
# United States Virgin Islands     Charlotte Amalie      200  VIR
# United States                    Washington, D.C.        3  USA
# ...
